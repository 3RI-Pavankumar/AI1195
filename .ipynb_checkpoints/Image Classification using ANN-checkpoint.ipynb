# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
(train_img, train_lab), (test_img, test_lab) = cifar10.load_data()

# %%
train_img.shape
# Out:
# (50000, 32, 32, 3)

# %%
train_img[34]
# Out:
# array([[[172, 187, 130],
#         [171, 186, 130],
#         [168, 182, 126],
#         ...,
#         [158, 170, 113],
#         [156, 169, 113],
#         [147, 163, 107]],
#
#        [[169, 185, 123],
#         [168, 183, 122],
#         [168, 184, 123],
#         ...,
#         [158, 175, 114],
#         [152, 170, 110],
#         [145, 165, 107]],
#
#        [[174, 190, 126],
#         [169, 185, 122],
#         [170, 186, 123],
#         ...,
#         [157, 177, 115],
#         [149, 170, 108],
#         [146, 168, 109]],
#
#        ...,
#
#        [[150, 163, 100],
#         [157, 168, 103],
#         [162, 170, 104],
#         ...,
#         [158, 168, 108],
#         [147, 160,  99],
#         [139, 154,  90]],
#
#        [[143, 154,  89],
#         [149, 158,  90],
#         [155, 161,  96],
#         ...,
#         [148, 157,  99],
#         [143, 153,  92],
#         [140, 153,  88]],
#
#        [[148, 158,  93],
#         [146, 155,  89],
#         [149, 157,  92],
#         ...,
#         [137, 143,  86],
#         [134, 139,  80],
#         [136, 143,  82]]], dtype=uint8)

# %%
train_lab[34]
# Out:
# array([4], dtype=uint8)

# %%
plt.figure(figsize=(3, 3))
plt.imshow(train_img[34])
plt.show()

# %%
classes = ["airplane", "automobile", "bird", "cat", "deer", "dog", "frog", "horse", "ship", "truck"]

# %%
for i in range(5):
    ind = np.random.randint(50000)
    plt.figure(figsize=(3, 3))
    plt.imshow(train_img[ind])
    plt.title(classes[train_lab[ind][0]])
    plt.show()

# %%
train_img.min()
# Out:
# 0

# %%
train_img.max()
# Out:
# 255

# %%
train_img[34]
# Out:
# array([[[172, 187, 130],
#         [171, 186, 130],
#         [168, 182, 126],
#         ...,
#         [158, 170, 113],
#         [156, 169, 113],
#         [147, 163, 107]],
#
#        [[169, 185, 123],
#         [168, 183, 122],
#         [168, 184, 123],
#         ...,
#         [158, 175, 114],
#         [152, 170, 110],
#         [145, 165, 107]],
#
#        [[174, 190, 126],
#         [169, 185, 122],
#         [170, 186, 123],
#         ...,
#         [157, 177, 115],
#         [149, 170, 108],
#         [146, 168, 109]],
#
#        ...,
#
#        [[150, 163, 100],
#         [157, 168, 103],
#         [162, 170, 104],
#         ...,
#         [158, 168, 108],
#         [147, 160,  99],
#         [139, 154,  90]],
#
#        [[143, 154,  89],
#         [149, 158,  90],
#         [155, 161,  96],
#         ...,
#         [148, 157,  99],
#         [143, 153,  92],
#         [140, 153,  88]],
#
#        [[148, 158,  93],
#         [146, 155,  89],
#         [149, 157,  92],
#         ...,
#         [137, 143,  86],
#         [134, 139,  80],
#         [136, 143,  82]]], dtype=uint8)

# %%
train_img[34]/255
# Out:
# array([[[0.6745098 , 0.73333333, 0.50980392],
#         [0.67058824, 0.72941176, 0.50980392],
#         [0.65882353, 0.71372549, 0.49411765],
#         ...,
#         [0.61960784, 0.66666667, 0.44313725],
#         [0.61176471, 0.6627451 , 0.44313725],
#         [0.57647059, 0.63921569, 0.41960784]],
#
#        [[0.6627451 , 0.7254902 , 0.48235294],
#         [0.65882353, 0.71764706, 0.47843137],
#         [0.65882353, 0.72156863, 0.48235294],
#         ...,
#         [0.61960784, 0.68627451, 0.44705882],
#         [0.59607843, 0.66666667, 0.43137255],
#         [0.56862745, 0.64705882, 0.41960784]],
#
#        [[0.68235294, 0.74509804, 0.49411765],
#         [0.6627451 , 0.7254902 , 0.47843137],
#         [0.66666667, 0.72941176, 0.48235294],
#         ...,
#         [0.61568627, 0.69411765, 0.45098039],
#         [0.58431373, 0.66666667, 0.42352941],
#         [0.57254902, 0.65882353, 0.42745098]],
#
#        ...,
#
#        [[0.58823529, 0.63921569, 0.39215686],
#         [0.61568627, 0.65882353, 0.40392157],
#         [0.63529412, 0.66666667, 0.40784314],
#         ...,
#         [0.61960784, 0.65882353, 0.42352941],
#         [0.57647059, 0.62745098, 0.38823529],
#         [0.54509804, 0.60392157, 0.35294118]],
#
#        [[0.56078431, 0.60392157, 0.34901961],
#         [0.58431373, 0.61960784, 0.35294118],
#         [0.60784314, 0.63137255, 0.37647059],
#         ...,
#         [0.58039216, 0.61568627, 0.38823529],
#         [0.56078431, 0.6       , 0.36078431],
#         [0.54901961, 0.6       , 0.34509804]],
#
#        [[0.58039216, 0.61960784, 0.36470588],
#         [0.57254902, 0.60784314, 0.34901961],
#         [0.58431373, 0.61568627, 0.36078431],
#         ...,
#         [0.5372549 , 0.56078431, 0.3372549 ],
#         [0.5254902 , 0.54509804, 0.31372549],
#         [0.53333333, 0.56078431, 0.32156863]]])

# %%
plt.figure(figsize=(3, 3))
plt.imshow(train_img[34]/255)
plt.show()

# %%
train_img, test_img = train_img/255. , test_img/255.

# %%
train_img[342]
# Out:
# array([[[0.16470588, 0.1254902 , 0.12941176],
#         [0.18039216, 0.14117647, 0.14509804],
#         [0.18431373, 0.14509804, 0.14901961],
#         ...,
#         [0.10196078, 0.07843137, 0.07058824],
#         [0.09411765, 0.0745098 , 0.0627451 ],
#         [0.09411765, 0.07058824, 0.05882353]],
#
#        [[0.17254902, 0.1254902 , 0.1254902 ],
#         [0.18823529, 0.14117647, 0.14117647],
#         [0.19215686, 0.14509804, 0.14509804],
#         ...,
#         [0.12156863, 0.09411765, 0.08627451],
#         [0.11764706, 0.08627451, 0.07843137],
#         [0.10980392, 0.07843137, 0.07058824]],
#
#        [[0.17254902, 0.11764706, 0.11372549],
#         [0.19215686, 0.14117647, 0.13333333],
#         [0.20392157, 0.14901961, 0.14509804],
#         ...,
#         [0.1372549 , 0.09803922, 0.09411765],
#         [0.13333333, 0.09411765, 0.09019608],
#         [0.12156863, 0.08235294, 0.07843137]],
#
#        ...,
#
#        [[0.46666667, 0.38823529, 0.36862745],
#         [0.49411765, 0.40392157, 0.38431373],
#         [0.51764706, 0.41568627, 0.39215686],
#         ...,
#         [0.40392157, 0.3254902 , 0.30196078],
#         [0.38431373, 0.30588235, 0.2745098 ],
#         [0.35294118, 0.27843137, 0.25882353]],
#
#        [[0.4627451 , 0.38431373, 0.36470588],
#         [0.48627451, 0.39607843, 0.37647059],
#         [0.52156863, 0.41960784, 0.39215686],
#         ...,
#         [0.40784314, 0.32941176, 0.30196078],
#         [0.38431373, 0.30588235, 0.27843137],
#         [0.36078431, 0.28235294, 0.2627451 ]],
#
#        [[0.44705882, 0.36862745, 0.34901961],
#         [0.47058824, 0.38431373, 0.36078431],
#         [0.50588235, 0.40784314, 0.38431373],
#         ...,
#         [0.39215686, 0.31372549, 0.28627451],
#         [0.38823529, 0.30980392, 0.28235294],
#         [0.34117647, 0.26666667, 0.24705882]]])

# %%
test_img[123]
# Out:
# array([[[0.80392157, 0.89019608, 0.47058824],
#         [0.80392157, 0.89019608, 0.47058824],
#         [0.80784314, 0.89411765, 0.4745098 ],
#         ...,
#         [0.81960784, 0.89411765, 0.5372549 ],
#         [0.81176471, 0.88627451, 0.5372549 ],
#         [0.80784314, 0.88235294, 0.5372549 ]],
#
#        [[0.80784314, 0.89803922, 0.4627451 ],
#         [0.80784314, 0.89411765, 0.4627451 ],
#         [0.80392157, 0.89019608, 0.45882353],
#         ...,
#         [0.82745098, 0.90196078, 0.52941176],
#         [0.81960784, 0.89411765, 0.53333333],
#         [0.81568627, 0.89411765, 0.52941176]],
#
#        [[0.79607843, 0.88627451, 0.44705882],
#         [0.79607843, 0.88235294, 0.44705882],
#         [0.79215686, 0.87843137, 0.44313725],
#         ...,
#         [0.80784314, 0.88627451, 0.49803922],
#         [0.80392157, 0.87843137, 0.50196078],
#         [0.8       , 0.87843137, 0.50196078]],
#
#        ...,
#
#        [[0.58823529, 0.69803922, 0.25490196],
#         [0.59215686, 0.69803922, 0.25882353],
#         [0.56862745, 0.67843137, 0.23529412],
#         ...,
#         [0.61960784, 0.70980392, 0.30980392],
#         [0.63137255, 0.71764706, 0.31372549],
#         [0.6       , 0.68627451, 0.29803922]],
#
#        [[0.59607843, 0.70588235, 0.25882353],
#         [0.56078431, 0.67058824, 0.22745098],
#         [0.56078431, 0.67058824, 0.22352941],
#         ...,
#         [0.6       , 0.68627451, 0.29411765],
#         [0.61176471, 0.69803922, 0.31372549],
#         [0.60392157, 0.68627451, 0.31764706]],
#
#        [[0.59215686, 0.70196078, 0.25882353],
#         [0.55294118, 0.65882353, 0.22352941],
#         [0.54509804, 0.65098039, 0.21176471],
#         ...,
#         [0.50980392, 0.59607843, 0.21960784],
#         [0.57254902, 0.65098039, 0.30196078],
#         [0.57647059, 0.65490196, 0.31764706]]])

# %%
model = Sequential([
    Flatten(input_shape = (32, 32, 3)),
    Dense(1000, activation="relu"),
    Dense(750, activation="relu"),
    Dense(500, activation="relu"),
    Dense(300, activation="relu"),
    Dense(200, activation="relu"),
    Dense(500, activation="relu"),
    Dense(750, activation="relu"),
    Dense(10, activation="softmax")
])

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %%
model.fit(train_img, train_lab, epochs=30, batch_size=32, validation_data=(test_img, test_lab))
# Out:
# Epoch 1/30
# 1563/1563 [==============================] - 64s 41ms/step - loss: 1.9957 - accuracy: 0.2352 - val_loss: 1.9057 - val_accuracy: 0.2732
# Epoch 2/30
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.8264 - accuracy: 0.3239 - val_loss: 1.7759 - val_accuracy: 0.3615
# Epoch 3/30
# 1563/1563 [==============================] - 83s 53ms/step - loss: 1.7585 - accuracy: 0.3580 - val_loss: 1.7584 - val_accuracy: 0.3652
# Epoch 4/30
# 1563/1563 [==============================] - 82s 53ms/step - loss: 1.6986 - accuracy: 0.3837 - val_loss: 1.6591 - val_accuracy: 0.3963
# Epoch 5/30
# 1563/1563 [==============================] - 81s 52ms/step - loss: 1.6450 - accuracy: 0.4062 - val_loss: 1.6375 - val_accuracy: 0.4064
# Epoch 6/30
# 1563/1563 [==============================] - 77s 49ms/step - loss: 1.6035 - accuracy: 0.4224 - val_loss: 1.5811 - val_accuracy: 0.4340
# Epoch 7/30
# 1563/1563 [==============================] - 79s 51ms/step - loss: 1.5724 - accuracy: 0.4326 - val_loss: 1.5695 - val_accuracy: 0.4399
# Epoch 8/30
# 1563/1563 [==============================] - 78s 50ms/step - loss: 1.5490 - accuracy: 0.4436 - val_loss: 1.5665 - val_accuracy: 0.4367
# Epoch 9/30
# 1563/1563 [==============================] - 82s 53ms/step - loss: 1.5169 - accuracy: 0.4553 - val_loss: 1.5454 - val_accuracy: 0.4409
# Epoch 10/30
# 1563/1563 [==============================] - 68s 43ms/step - loss: 1.4992 - accuracy: 0.4631 - val_loss: 1.5238 - val_accuracy: 0.4593
# Epoch 11/30
# 1563/1563 [==============================] - 83s 53ms/step - loss: 1.4752 - accuracy: 0.4732 - val_loss: 1.4985 - val_accuracy: 0.4657
# Epoch 12/30
# 1563/1563 [==============================] - 71s 45ms/step - loss: 1.4560 - accuracy: 0.4765 - val_loss: 1.5067 - val_accuracy: 0.4666
# Epoch 13/30
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.4370 - accuracy: 0.4843 - val_loss: 1.4907 - val_accuracy: 0.4737
# Epoch 14/30
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.4268 - accuracy: 0.4895 - val_loss: 1.5091 - val_accuracy: 0.4659
# Epoch 15/30
# 1563/1563 [==============================] - 69s 44ms/step - loss: 1.4066 - accuracy: 0.4953 - val_loss: 1.5036 - val_accuracy: 0.4760
# Epoch 16/30
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.3945 - accuracy: 0.4991 - val_loss: 1.5115 - val_accuracy: 0.4648
# Epoch 17/30
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.3790 - accuracy: 0.5041 - val_loss: 1.5115 - val_accuracy: 0.4678
# Epoch 18/30
# 1563/1563 [==============================] - 82s 52ms/step - loss: 1.3619 - accuracy: 0.5114 - val_loss: 1.4821 - val_accuracy: 0.4791
# Epoch 19/30
# 1563/1563 [==============================] - 62s 40ms/step - loss: 1.3524 - accuracy: 0.5158 - val_loss: 1.5131 - val_accuracy: 0.4719
# Epoch 20/30
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.3353 - accuracy: 0.5200 - val_loss: 1.4879 - val_accuracy: 0.4776
# Epoch 21/30
# 1563/1563 [==============================] - 86s 55ms/step - loss: 1.3225 - accuracy: 0.5252 - val_loss: 1.5343 - val_accuracy: 0.4637
# Epoch 22/30
# 1563/1563 [==============================] - 74s 47ms/step - loss: 1.3065 - accuracy: 0.5304 - val_loss: 1.5554 - val_accuracy: 0.4651
# Epoch 23/30
# 1563/1563 [==============================] - 65s 42ms/step - loss: 1.2945 - accuracy: 0.5361 - val_loss: 1.5174 - val_accuracy: 0.4722
# Epoch 24/30
# 1563/1563 [==============================] - 76s 49ms/step - loss: 1.2813 - accuracy: 0.5406 - val_loss: 1.5732 - val_accuracy: 0.4549
# Epoch 25/30
# 1563/1563 [==============================] - 75s 48ms/step - loss: 1.2630 - accuracy: 0.5466 - val_loss: 1.5267 - val_accuracy: 0.4771
# Epoch 26/30
# 1563/1563 [==============================] - 73s 47ms/step - loss: 1.2533 - accuracy: 0.5520 - val_loss: 1.5339 - val_accuracy: 0.4707
# Epoch 27/30
# 1563/1563 [==============================] - 72s 46ms/step - loss: 1.2351 - accuracy: 0.5546 - val_loss: 1.5284 - val_accuracy: 0.4791
# Epoch 28/30
# 1563/1563 [==============================] - 68s 43ms/step - loss: 1.2241 - accuracy: 0.5626 - val_loss: 1.5310 - val_accuracy: 0.4786
# Epoch 29/30
# 1563/1563 [==============================] - 71s 46ms/step - loss: 1.2188 - accuracy: 0.5627 - val_loss: 1.5559 - val_accuracy: 0.4750
# Epoch 30/30
# 1563/1563 [==============================] - 70s 45ms/step - loss: 1.1927 - accuracy: 0.5727 - val_loss: 1.5781 - val_accuracy: 0.4813

# %%
plt.figure(figsize=(12, 4))
plt.plot(model.history.history["loss"], label="Training Loss")
plt.plot(model.history.history["val_loss"], label="Validation Loss")
plt.title("Loss Visualization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.show()

# %%
plt.figure(figsize=(12, 4))
plt.plot(model.history.history["accuracy"], label="Training Accuracy")
plt.plot(model.history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Accuracy Visualization")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.show()

# %%
def image_predictor(img_path):
    img = load_img(img_path, target_size=(32, 32))
    img_arr = img_to_array(img)
    img_norm = img_arr / 255.0
    img_flatten = np.expand_dims(img_norm, axis=0)
    pred = model.predict(img_flatten)
    predicted_class = classes[np.argmax(pred[0])]
    return predicted_class

# %%
image_predictor("car.jpg")
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 'automobile'

# %%
image_predictor("ship.jpg")
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 'airplane'

# %%
image_predictor("deer.jpg")
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 'bird'

# %%
image_predictor("plane.jpg")
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 'airplane'
